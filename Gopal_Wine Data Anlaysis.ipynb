# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_red = pd.read_csv("D:/Data Analysis/Assignment Wine/winequality-red.csv",sep = ";")
df_white = pd.read_csv("D:/Data Analysis/Assignment Wine/winequality-white.csv",sep = ";")

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_red.iloc[100:111]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
# 110            7.8             0.560         0.19             1.8      0.104
#
# ...

# %%
df_white.iloc[100:111]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            7.4             0.250         0.37            13.5      0.060
# 101            7.1             0.120         0.32             9.6      0.054
# 102            6.0             0.210         0.24            12.1      0.050
# 103            7.5             0.305         0.40            18.9      0.059
# 104            7.4             0.250         0.37            13.5      0.060
# 105            7.3             0.130         0.32            14.4      0.051
# 106            7.1             0.120         0.32             9.6      0.054
# 107            7.1             0.230         0.35            16.5      0.040
# 108            7.1             0.230         0.35            16.5      0.040
# 109            6.9             0.330         0.28             1.3      0.051
# 110            6.5             0.170         0.54             8.5      0.082
#
# ...

# %%
df_red.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_red.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
df_white.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
# ...

# %%
df_red.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_red.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df_red.corr(),linewidths=1,annot = True)
# Out:
# <AxesSubplot:>

# %%
df_red.corr()['quality'].plot(kind='bar',grid=True)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (8,6))
sns.barplot(x = 'quality', y = 'alcohol', data = df_red)
plt.title("Positive Correlation between Alcohol and Quality")
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.lineplot(y = 'pH', x = 'alcohol', data = df_red)
plt.title("Weak Positive Correlation between Alcohol and pH Value")
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
sns.lineplot(y = 'fixed acidity', x = 'citric acid', data = df_red)
plt.title("Correlation between citric acid and fixed acidity")
plt.show()

fig = plt.figure(figsize = (8,6))
sns.lineplot(y = 'fixed acidity', x = 'density', data = df_red)
plt.title("Correlation between fixed acidity and density ")
plt.show()

# %%
fig = plt.figure(figsize = (8,6))
df_red.corr()['pH'].plot(kind='bar',grid=True)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (8,6))
sns.boxplot(x='quality', y='alcohol', data=df_red)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
joint_plt = sns.jointplot(x='alcohol', y='pH', data=df_red,
                        kind='reg')

# %%
from scipy.stats import pearsonr
def get_corr(col1, col2, temp_df):
    pearson_corr, p_value = pearsonr(temp_df[col1], temp_df[col2])
    print("Correlation between {} and {} is {}".format(col1, col2, pearson_corr))
    print("P-value of this correlation is {}".format(p_value))

# %%
get_corr('alcohol', 'pH', df_red)
# Out:
# Correlation between alcohol and pH is 0.20563250850549838
# P-value of this correlation is 9.964497741464427e-17

# %%
oint_plt = sns.jointplot(x='alcohol', y='density', data=df_red,
                        kind='reg')

# %%
get_corr('alcohol', 'density', df_red)
# Out:
# Correlation between alcohol and density is -0.4961797702417019
# P-value of this correlation is 3.9388353399903646e-100

# %%
fig = plt.figure(figsize = (8,6))
g = sns.FacetGrid(df_red, col="quality")
g = g.map(sns.regplot, "density", "alcohol")

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print("white mean = ",df_white["quality"].mean())
print("red mean =",df_red["quality"].mean())
# Out:
# white mean =  5.87790935075541
# red mean = 5.6360225140712945

# %%
d = {'color': ['red','white'], 'mean_quality': [5.636023,5.877909]}
df_mean = pd.DataFrame(data=d)
df_mean
# Out:
#    color  mean_quality
# 0    red      5.636023
# 1  white      5.877909

# %%
fig = plt.figure(figsize = (8,6))
sns.barplot(x = 'color', y = 'mean_quality', data = df_mean)
plt.title("Average Quality by Wine Color")
plt.show()

# %%
df_r_corr=df_red.corr()
df_w_corr=df_white.corr()

# %%
diff_corr = df_r_corr - df_w_corr

# %%
plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title("Correlation Differences between Red and White Wines")
corr = diff_corr
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="coolwarm")
# Out:
# <AxesSubplot:title={'center':'Correlation Differences between Red and White Wines'}>

# %%
df_red['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df_white['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='quality',data= df_red)
plt.title('red wine quality count')
plt.subplot(1,2,2)
sns.countplot(x='quality',data= df_white)
plt.title('white wine quality count');

# %%
df_red['wine category']= df_red['quality'].apply(lambda x :'low' if x <= 5 else ('medium' if x>5 and x<=7 else 'high' ))

# %%
df_red.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality wine category
# 0      9.4        5           low
# ...

# %%
df_white['wine category']= df_white['quality'].apply(lambda x :'low' if x <= 5 else ('medium' if x>5 and x<=7 else 'high' ))

# %%
df_white.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality wine category
# 0      8.8        6        medium
# ...

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='wine category',data= df_red)
plt.title('red wine category count')
plt.subplot(1,2,2)
sns.countplot(x='wine category',data= df_white)
plt.title('white wine category count');

# %%
df_red['label'] = 'red'
df_white['label']= 'white'

# %%
df_wines = pd.concat([df_red,df_white],ignore_index= True)
df_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
a = df_wines.value_counts(["wine category", "label"])
a
# Out:
# wine category  label
# medium         white    3078
# low            white    1640
# medium         red       837
# low            red       744
# high           white     180
#                red        18
# dtype: int64

# %%
df_wines.sort_values(by=['quality'])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 5409            6.8             0.260         0.34           15.10      0.060
# 2339            6.9             0.390         0.40            4.60      0.022
# 3016            8.6             0.550         0.35           15.55      0.057
# 1478            7.1             0.875         0.05            5.70      0.082
# 459            11.6             0.580         0.66            2.20      0.074
# ...             ...               ...          ...             ...        ...
# 2475            6.9             0.360         0.34            4.20      0.018
# 2426            7.4             0.240         0.36            2.00      0.031
# 2373            9.1             0.270         0.45           10.60      0.035
# 2419            6.6             0.360         0.29            1.60      0.021
# 3204            7.1             0.260         0.49            2.20      0.032
#
# ...

# %%
df_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine category         6497 non-null   object
#  13  label                 6497 non-null   object
# dtypes: float64(11), int64(1), object(2)
# ...

# %%
df_wines.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free sulfur dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total sulfur dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
# ...

# %%
df_wines.sample(frac=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 123             8.0              0.71         0.00            2.60      0.080
# 2299            8.4              0.40         0.70           13.10      0.042
# 1454           11.7              0.45         0.63            2.20      0.073
# 4441            5.9              0.20         0.40            1.30      0.047
# 3383            6.7              0.24         0.29            6.80      0.038
# ...             ...               ...          ...             ...        ...
# 958             6.4              0.57         0.12            2.30      0.120
# 2903            8.0              0.59         0.71           17.35      0.038
# 4405            7.5              0.17         0.71           11.80      0.038
# 3582            7.6              0.20         0.30           14.20      0.056
# 2939            7.2              0.16         0.32            0.80      0.040
#
# ...

# %%
wines_df = df_wines.iloc[:,[7,8,10,11,12]]
wines_df
# Out:
#       density    pH  alcohol  quality wine category
# 0     0.99780  3.51      9.4        5           low
# 1     0.99680  3.20      9.8        5           low
# 2     0.99700  3.26      9.8        5           low
# 3     0.99800  3.16      9.8        6        medium
# 4     0.99780  3.51      9.4        5           low
# ...       ...   ...      ...      ...           ...
# 6492  0.99114  3.27     11.2        6        medium
# 6493  0.99490  3.15      9.6        5           low
# 6494  0.99254  2.99      9.4        6        medium
# 6495  0.98869  3.34     12.8        7        medium
# 6496  0.98941  3.26     11.8        6        medium
#
# [6497 rows x 5 columns]

# %%
df_low = wines_df[wines_df['wine category']=='low']
df_medium = wines_df[wines_df['wine category']=='medium']
df_high = wines_df[wines_df['wine category']=='high']

# %%
wines_new_df = pd.concat([df_high,df_medium,df_low])
wines_new_df
# Out:
#       density    pH  alcohol  quality wine category
# 267   0.99730  3.35     12.8        8          high
# 278   0.99760  3.23     12.6        8          high
# 390   0.99240  3.56     12.9        8          high
# 440   0.99870  2.88      9.8        8          high
# 455   0.99880  3.22     13.4        8          high
# ...       ...   ...      ...      ...           ...
# 6481  0.99184  3.26     10.7        5           low
# 6483  0.99492  3.14      9.6        5           low
# 6487  0.99330  3.04      9.2        5           low
# 6491  0.99298  3.29      9.7        5           low
# 6493  0.99490  3.15      9.6        5           low
#
# [6497 rows x 5 columns]

# %%
wines_new_df.corr()
# Out:
#           density        pH   alcohol   quality
# density  1.000000  0.011686 -0.686745 -0.305858
# pH       0.011686  1.000000  0.121248  0.019506
# alcohol -0.686745  0.121248  1.000000  0.444319
# quality -0.305858  0.019506  0.444319  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_wines.corr(),annot=True, cmap = "Blues")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
sns.scatterplot(x= 'alcohol',y=wines_new_df.index,data=wines_new_df,hue='wine category')
plt.title('Category analysis with respect to Alcohol (univariate)');

# %%
sns.countplot(x='wine category',data= df_wines)
# Out:
# <AxesSubplot:xlabel='wine category', ylabel='count'>
